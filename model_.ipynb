# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("diabetic_data.csv")

# %%
mask = (
    (df[["diag_1", "diag_2", "diag_3"]] == "?").any(axis=1)
    | (df["race"] == "?")
    | (df["discharge_disposition_id"] == 11)
    | (df["gender"] == "Unknown/Invalid")
)
df = df[~mask]

df["admission_type_id"] = df["admission_type_id"].replace({2:1, 7:1, 6:5, 8:5})

df["discharge_disposition_id"] = df["discharge_disposition_id"].replace({
    6:1, 8:1, 9:1, 13:1,
    3:2, 4:2, 5:2, 14:2, 22:2, 23:2, 24:2,
    12:10, 15:10, 16:10, 17:10,
    25:18, 26:18
})

df["admission_source_id"] = df["admission_source_id"].replace({
    2:1, 3:1,
    5:4, 6:4, 10:4, 22:4, 25:4,
    15:9, 17:9, 20:9, 21:9,
    13:11, 14:11
})

df["change"] = df["change"].replace({"Ch":1, "No":0})
df["gender"] = df["gender"].replace({"Male":1, "Female":0})
df["diabetesMed"] = df["diabetesMed"].replace({"Yes":1, "No":0})
df["A1Cresult"] = df["A1Cresult"].replace({">7":1, ">8":1, "Norm":0, "None":-99})
df["max_glu_serum"] = df["max_glu_serum"].replace({">200":1, ">300":1, "Norm":0, "None":-99})
df["readmitted"] = df["readmitted"].replace({">30":0, "<30":1, "NO":0})

age_mapping = {f"[{i*10}-{(i+1)*10})": i+1 for i in range(10)}
df["age"] = df["age"].replace(age_mapping)

df = df.drop_duplicates(subset=["patient_nbr"], keep="first")
df = df.drop(["weight", "payer_code", "medical_specialty"], axis=1)

# %%
df.head()
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses',
#        'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose',
#        'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton',
#        'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
med_columns = [
    "metformin","repaglinide","nateglinide","chlorpropamide","glimepiride",
    "acetohexamide","glipizide","glyburide","tolbutamide","pioglitazone",
    "rosiglitazone","acarbose","miglitol","troglitazone","tolazamide",
    "insulin","glyburide-metformin","glipizide-metformin",
    "glimepiride-pioglitazone","metformin-rosiglitazone",
    "metformin-pioglitazone","change","diabetesMed"
]

categorical_cols = [
    "gender","admission_type_id","discharge_disposition_id",
    "admission_source_id","max_glu_serum","A1Cresult","race"
] + med_columns

numeric_cols = [
    "age","time_in_hospital","num_procedures","num_medications",
    "number_outpatient","number_emergency",
    "number_inpatient","number_diagnoses"
]

df[numeric_cols] = df[numeric_cols].astype(float)
df[numeric_cols] = (df[numeric_cols] - df[numeric_cols].mean()) / df[numeric_cols].std()

df = df[(np.abs(sp.stats.zscore(df[numeric_cols])) < 3).all(axis=1)]

df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

numeric_features = [
    "age",
    "time_in_hospital",
    "num_procedures",
    "num_medications",
    "number_outpatient",
    "number_emergency",
    "number_inpatient",
    "number_diagnoses",
]

dummy_features = [
    col for col in df_encoded.columns
    if col not in numeric_features + ["readmitted"]
    and df_encoded[col].dtype != "object"
]

X = df_encoded[numeric_features + dummy_features]
y = df_encoded["readmitted"]

# %%
X_majority = X[y == 0]
X_minority = X[y == 1]

X_minority_upsampled = resample(
    X_minority, replace=True, n_samples=len(X_majority), random_state=20
)

X_balanced = pd.concat([X_majority, X_minority_upsampled])
y_balanced = pd.Series([0]*len(X_majority) + [1]*len(X_minority_upsampled))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, test_size=0.2, random_state=0
)

# %%
X_train.head()
# Out:
#             age  time_in_hospital  num_procedures  num_medications  \
# 48842  0.586481          1.929768        2.026773         2.206957
# 30771 -0.055226         -0.784103       -0.816778        -1.545744
# 37591  1.228187          1.590534       -0.816778         0.633243
# 92154 -1.338639          0.233598        2.595483         1.722737
# 99605  1.228187          0.233598        2.595483         1.601683
#
#        number_outpatient  number_emergency  number_inpatient  \
# 48842          -0.265606         -0.205757         -0.300361
# 30771          -0.265606         -0.205757         -0.300361
# 37591           0.659920         -0.205757         -0.300361
# 92154          -0.265606         -0.205757         -0.300361
# 99605           0.659920         -0.205757         -0.300361
#
#        number_diagnoses  encounter_id  patient_nbr  ...  insulin_No  \
# 48842          0.881747     148521936     62415576  ...       False
# 30771         -0.175977      99258660    112308831  ...        True
# 37591          0.881747     116650068     75169485  ...        True
# 92154          0.881747     318460610    131542403  ...       False
# 99605          0.881747     415471526    174098516  ...       False
#
#        insulin_Steady  insulin_Up  glyburide-metformin_No  \
# 48842            True       False                    True
# 30771           False       False                    True
# 37591           False       False                    True
# 92154            True       False                    True
# 99605           False        True                    True
#
#        glyburide-metformin_Steady  glyburide-metformin_Up  \
# 48842                       False                   False
# 30771                       False                   False
# 37591                       False                   False
# 92154                       False                   False
# 99605                       False                   False
#
#        glipizide-metformin_Steady  metformin-pioglitazone_Steady  change_1  \
# 48842                       False                          False      True
# 30771                       False                          False     False
# 37591                       False                          False     False
# 92154                       False                          False     False
# 99605                       False                          False      True
#
#        diabetesMed_1
# 48842           True
# 30771          False
# 37591          False
# 92154           True
# 99605           True
#
# [5 rows x 79 columns]

# %%
rf = RandomForestClassifier(
    n_estimators=10, max_depth=25, min_samples_split=10, random_state=0
)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)

print("\n--- Random Forest ---")
print("Accuracy:", accuracy_score(y_test, rf_pred))
print("Precision:", precision_score(y_test, rf_pred))
print("Recall:", recall_score(y_test, rf_pred))
# Out:
# --- Random Forest ---
# Accuracy: 0.9590735623108304
# Precision: 0.9415204678362573
# Recall: 0.979744414500565

# %%
dnn = Sequential([
    Dense(128, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

dnn.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

dnn.fit(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=0
)

dnn_pred = (dnn.predict(X_test) > 0.5).astype(int).ravel()

print("\n--- Deep Neural Network ---")
print("Accuracy:", accuracy_score(y_test, dnn_pred))
print("Precision:", precision_score(y_test, dnn_pred))
print("Recall:", recall_score(y_test, dnn_pred))
# Out:
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# --- Deep Neural Network ---
# Accuracy: 0.49541606351712947
# Precision: 0.0
# Recall: 0.0

# %%
dnn_small = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(1, activation="sigmoid")
])

dnn_small.compile(
    optimizer=Adam(learning_rate=0.005),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

dnn_small.fit(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)

pred_small = (dnn_small.predict(X_test) > 0.5).astype(int).ravel()

print("\n--- DNN Small ---")
print("Accuracy:", accuracy_score(y_test, pred_small))
print("Precision:", precision_score(y_test, pred_small))
print("Recall:", recall_score(y_test, pred_small))
# Out:
# Epoch 1/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5010 - loss: 101799.9922 - val_accuracy: 0.4981 - val_loss: 48.6381
# Epoch 2/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5008 - loss: 12.0910 - val_accuracy: 0.5025 - val_loss: 0.8343
# Epoch 3/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.4992 - loss: 0.9603 - val_accuracy: 0.5011 - val_loss: 0.7122
# Epoch 4/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4970 - loss: 0.7117 - val_accuracy: 0.4993 - val_loss: 0.6942
# Epoch 5/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4985 - loss: 0.6935 - val_accuracy: 0.4992 - val_loss: 0.6932
# Epoch 6/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5003 - loss: 0.6932 - val_accuracy: 0.5008 - val_loss: 0.6936
# Epoch 7/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5007 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 8/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5010 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 9/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5002 - loss: 0.6932 - val_accuracy: 0.4989 - val_loss: 0.6936
# Epoch 10/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4973 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 11/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4991 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 12/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5029 - loss: 0.6932 - val_accuracy: 0.4989 - val_loss: 0.6937
# Epoch 13/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5034 - loss: 0.6932 - val_accuracy: 0.4989 - val_loss: 0.6936
# Epoch 14/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5005 - loss: 0.6932 - val_accuracy: 0.4989 - val_loss: 0.6936
# Epoch 15/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4995 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 16/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5002 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 17/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4981 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 18/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5021 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6934
# Epoch 19/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4995 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 20/20
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5022 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6933
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# --- DNN Small ---
# Accuracy: 0.49541606351712947
# Precision: 0.0
# Recall: 0.0

# %%
dnn_medium = Sequential([
    Dense(128, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(32, activation="relu"),
    Dense(1, activation="sigmoid")
])

dnn_medium.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

dnn_medium.fit(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=0
)

pred_medium = (dnn_medium.predict(X_test) > 0.5).astype(int).ravel()

print("\n--- DNN Medium ---")
print("Accuracy:", accuracy_score(y_test, pred_medium))
print("Precision:", precision_score(y_test, pred_medium))
print("Recall:", recall_score(y_test, pred_medium))
# Out:
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- DNN Medium ---
# Accuracy: 0.5045839364828706
# Precision: 0.5045839364828706
# Recall: 1.0

# %%
dnn_deep = Sequential([
    Dense(256, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.4),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dense(1, activation="sigmoid")
])

dnn_deep.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

dnn_deep.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2,
    verbose=0
)

pred_deep = (dnn_deep.predict(X_test) > 0.5).astype(int).ravel()

print("\n--- DNN Deep ---")
print("Accuracy:", accuracy_score(y_test, pred_deep))
print("Precision:", precision_score(y_test, pred_deep))
print("Recall:", recall_score(y_test, pred_deep))
# Out:
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- DNN Deep ---
# Accuracy: 0.5045839364828706
# Precision: 0.5045839364828706
# Recall: 1.0

# %%
dnn_final = Sequential([
    Dense(128, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

dnn_final.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

dnn_final.fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)

dnn_pred = (dnn_final.predict(X_test) > 0.5).astype(int).ravel()

print("\n--- Deep Neural Network ---")
print("Accuracy:", accuracy_score(y_test, dnn_pred))
print("Precision:", precision_score(y_test, dnn_pred))
print("Recall:", recall_score(y_test, dnn_pred))
# Out:
# Epoch 1/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4962 - loss: 60443.2383 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 2/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5018 - loss: 32.4341 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 3/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5021 - loss: 11.5659 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 4/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5020 - loss: 9.5213 - val_accuracy: 0.4989 - val_loss: 0.6938
# Epoch 5/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4944 - loss: 59.3125 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 6/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4995 - loss: 46.1277 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 7/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5014 - loss: 76.4298 - val_accuracy: 0.4989 - val_loss: 0.6935
# Epoch 8/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4999 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 9/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4996 - loss: 13.9677 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 10/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5011 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 11/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5001 - loss: 3.4432 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 12/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5020 - loss: 36.7558 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 13/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5012 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 14/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5037 - loss: 44.6719 - val_accuracy: 0.4989 - val_loss: 0.6934
# Epoch 15/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4992 - loss: 7.2349 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 16/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4992 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6935
# Epoch 17/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4981 - loss: 30.1568 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 18/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4989 - loss: 7.8161 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 19/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4988 - loss: 7.6966 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 20/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4987 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 21/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4989 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6934
# Epoch 22/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4999 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 23/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5010 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 24/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4970 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6935
# Epoch 25/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5000 - loss: 5.4858 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 26/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4956 - loss: 221.9283 - val_accuracy: 0.4989 - val_loss: 0.6936
# Epoch 27/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5005 - loss: 1.5491 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 28/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4985 - loss: 17.5363 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 29/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4992 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6935
# Epoch 30/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5033 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 31/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5004 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6935
# Epoch 32/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4990 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6934
# Epoch 33/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5005 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6937
# Epoch 34/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5023 - loss: 2.9859 - val_accuracy: 0.4989 - val_loss: 0.6934
# Epoch 35/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4987 - loss: 0.6934 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 36/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5024 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 37/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4974 - loss: 0.6934 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 38/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4971 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 39/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5022 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 40/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4971 - loss: 0.6934 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 41/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5018 - loss: 0.6932 - val_accuracy: 0.4989 - val_loss: 0.6934
# Epoch 42/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4993 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 43/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5010 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 44/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5002 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6935
# Epoch 45/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5006 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 46/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4990 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 47/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4995 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 48/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5009 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6934
# Epoch 49/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5003 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 50/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5010 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 51/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4971 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 52/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4977 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 53/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5017 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 54/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5016 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 55/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4975 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 56/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5023 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 57/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4970 - loss: 0.6934 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 58/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5005 - loss: 4.1358 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 59/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4988 - loss: 32.4539 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 60/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4976 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 61/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.4998 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 62/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4976 - loss: 5.5429 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 63/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5002 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 64/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4994 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 65/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4995 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6934
# Epoch 66/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5020 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6935
# Epoch 67/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4968 - loss: 5.9717 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 68/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4979 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 69/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4998 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 70/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5004 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6936
# Epoch 71/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4979 - loss: 0.6934 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 72/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4989 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 73/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5007 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 74/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4974 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 75/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5016 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 76/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4988 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 77/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5023 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 78/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4976 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 79/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4999 - loss: 109.9424 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 80/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4993 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 81/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5000 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 82/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5004 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 83/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4979 - loss: 0.6934 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 84/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.4990 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6939
# Epoch 85/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4994 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 86/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5030 - loss: 0.6932 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 87/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5028 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 88/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4987 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 89/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4999 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 90/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4998 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6937
# Epoch 91/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4997 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 92/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4996 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 93/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4963 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6933
# Epoch 94/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5028 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6934
# Epoch 95/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5018 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6933
# Epoch 96/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5021 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 97/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5017 - loss: 0.6933 - val_accuracy: 0.4989 - val_loss: 0.6932
# Epoch 98/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4967 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6931
# Epoch 99/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5005 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# Epoch 100/100
# 1140/1140 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5010 - loss: 0.6933 - val_accuracy: 0.5011 - val_loss: 0.6932
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# --- Deep Neural Network ---
# Accuracy: 0.49541606351712947
# Precision: 0.0
# Recall: 0.0

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    penalty="l1",
    solver="liblinear",
    fit_intercept=True,
    max_iter=100
)

lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

print("\n--- Logistic Regression ---")
print("Accuracy:", accuracy_score(y_test, lr_pred))
print("Precision:", precision_score(y_test, lr_pred))
print("Recall:", recall_score(y_test, lr_pred))
# Out:
# --- Logistic Regression ---
# Accuracy: 0.6070096942580164
# Precision: 0.6250245724395518
# Recall: 0.5528123098322176

# %%
models_preds = {
    "Logistic Regression": (lr, lr.predict(X_train), lr.predict(X_test)),
    "Random Forest": (rf, rf.predict(X_train), rf.predict(X_test)),
    "Deep Neural Network": (
        dnn_deep,
        (dnn_deep.predict(X_train) > 0.5).astype(int).ravel(),
        (dnn_deep.predict(X_test) > 0.5).astype(int).ravel(),
    ),
}

metrics = {"accuracy": accuracy_score, "precision": precision_score, "recall": recall_score}

results = {}

for model_name, (_, y_train_pred, y_test_pred) in models_preds.items():
    results[model_name] = {
        "train": {m: metrics[m](y_train, y_train_pred) for m in metrics},
        "test": {m: metrics[m](y_test, y_test_pred) for m in metrics},
    }
# Out:
# 2850/2850 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

for metric in ["accuracy", "precision", "recall"]:
    plt.figure(figsize=(8, 5))
    x = np.arange(len(results))
    width = 0.35

    train_scores = [results[m]["train"][metric] for m in results]
    test_scores = [results[m]["test"][metric] for m in results]

    plt.bar(x - width/2, train_scores, width, label="Train")
    plt.bar(x + width/2, test_scores, width, label="Test")

    plt.xticks(x, results.keys(), rotation=15)
    plt.ylabel(metric.capitalize())
    plt.title(f"Train vs Test {metric.capitalize()}")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
train_table = pd.DataFrame({
    "Model": results.keys(),
    "Accuracy": [results[m]["train"]["accuracy"] for m in results],
    "Precision": [results[m]["train"]["precision"] for m in results],
    "Recall": [results[m]["train"]["recall"] for m in results],
})

train_table = train_table.set_index("Model")
print("\nTrain Performance")
display(train_table)
# Out:
# Train Performance
#                      Accuracy  Precision    Recall
# Model
# Logistic Regression  0.604310   0.615881  0.549552
# Random Forest        0.985327   0.980937  0.989821
# Deep Neural Network  0.498854   0.498854  1.000000

# %%
test_table = pd.DataFrame({
    "Model": results.keys(),
    "Accuracy": [results[m]["test"]["accuracy"] for m in results],
    "Precision": [results[m]["test"]["precision"] for m in results],
    "Recall": [results[m]["test"]["recall"] for m in results],
})

test_table = test_table.set_index("Model")
print("\nTest Performance")
display(test_table)
# Out:
# Test Performance
#                      Accuracy  Precision    Recall
# Model
# Logistic Regression  0.607010   0.625025  0.552812
# Random Forest        0.959074   0.941520  0.979744
# Deep Neural Network  0.504584   0.504584  1.000000

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

test_preds = {
    "Logistic Regression": lr_pred,
    "Random Forest": rf_pred,
    "Deep Neural Network": dnn_pred,
}

for model_name, y_pred in test_preds.items():
    cm = confusion_matrix(y_test, y_pred)

    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=["No Readmission", "Readmitted"]
    )

    disp.plot(cmap="Blues", values_format="d")
    plt.title(f"{model_name} – Test Confusion Matrix")
    plt.tight_layout()
    plt.show()
